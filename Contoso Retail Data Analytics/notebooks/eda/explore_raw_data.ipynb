# %% [markdown]
# # Script: explore_raw_data.py
# Purpose: Quick EDA to understand data in the raw folder

# %%
import pandas as pd
import os

# %%
RAW_DIR = r"C:\Users\Mohan\Downloads\sample\data\raw"
FILES = sorted([f for f in os.listdir(RAW_DIR) if f.endswith(".csv")])

for fname in FILES:
    path = os.path.join(RAW_DIR, fname)
    # Customers.csv has non-UTF-8 characters, use latin1
    encoding = "latin1" if fname == "Customers.csv" else "utf-8"
    df = pd.read_csv(path, encoding=encoding)

    print(f"{'='*60}")
    print(f"  FILE: {fname}")
    print(f"{'='*60}")
    print(f"  Shape: {df.shape[0]} rows x {df.shape[1]} columns")
    print(f"  Columns: {list(df.columns)}")
    print(f"\n  Data Types:")
    for col, dtype in df.dtypes.items():
        print(f"    {col}: {dtype}")
    
    print(f"\n  Missing Values:")
    missing = df.isnull().sum()
    missing_pct = (missing / len(df) * 100).round(1)
    for col in df.columns:
        if missing[col] > 0:
            print(f"    {col}: {missing[col]} missing ({missing_pct[col]}%)")
        else:
            print(f"    {col}: 0 missing")
    
    print(f"\n  Duplicate Rows: {df.duplicated().sum()}")

    # Show first 2 rows as a preview
    print(f"\n  First 2 rows:")
    print(df.head(2).to_string(index=False))

    print()

# Additional cross-table observations
print(f"{'='*60}")
print("  CROSS-TABLE OBSERVATIONS")
print(f"{'='*60}")

# Key relationships
print("""
  RELATIONSHIPS BETWEEN TABLES:
    - Sales.CustomerKey  -> Customers.CustomerKey
    - Sales.StoreKey     -> Stores.StoreKey
    - Sales.ProductKey   -> Products.ProductKey
    - Sales.CurrencyCode + Sales.Order Date -> Exchange_Rates.Currency + Exchange_Rates.Date
""")
# Out:
# ============================================================
#   FILE: Customers.csv
# ============================================================
#   Shape: 15266 rows x 10 columns
#   Columns: ['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State', 'Zip Code', 'Country', 'Continent', 'Birthday']
#
#   Data Types:
#     CustomerKey: int64
#     Gender: object
#     Name: object
#     City: object
#     State Code: object
#     State: object
#     Zip Code: object
#     Country: object
#     Continent: object
#     Birthday: object
#
#   Missing Values:
#     CustomerKey: 0 missing
#     Gender: 0 missing
#     Name: 0 missing
#     City: 0 missing
#     State Code: 10 missing (0.1%)
#     State: 0 missing
#     Zip Code: 0 missing
#     Country: 0 missing
#     Continent: 0 missing
#     Birthday: 0 missing
#
#   Duplicate Rows: 0
#
#   First 2 rows:
#  CustomerKey Gender          Name           City State Code             State Zip Code   Country Continent  Birthday
#          301 Female Lilly Harding WANDEARAH EAST         SA   South Australia     5523 Australia Australia  7/3/1939
#          325 Female  Madison Hull     MOUNT BUDD         WA Western Australia     6522 Australia Australia 9/27/1979
#
# ============================================================
#   FILE: Data_Dictionary.csv
# ============================================================
#   Shape: 37 rows x 3 columns
#   Columns: ['Table', 'Field', 'Description']
#
#   Data Types:
#     Table: object
#     Field: object
#     Description: object
#
#   Missing Values:
#     Table: 0 missing
#     Field: 0 missing
#     Description: 0 missing
#
#   Duplicate Rows: 0
#
#   First 2 rows:
# Table        Field                                                  Description
# Sales Order Number                                     Unique ID for each order
# Sales    Line Item Identifies individual products purchased as part of an order
#
# ============================================================
#   FILE: Exchange_Rates.csv
# ============================================================
#   Shape: 11215 rows x 3 columns
#   Columns: ['Date', 'Currency', 'Exchange']
#
#   Data Types:
#     Date: object
#     Currency: object
#     Exchange: float64
#
#   Missing Values:
#     Date: 0 missing
#     Currency: 0 missing
#     Exchange: 0 missing
#
#   Duplicate Rows: 0
#
#   First 2 rows:
#     Date Currency  Exchange
# 1/1/2015      USD    1.0000
# 1/1/2015      CAD    1.1583
#
# ============================================================
#   FILE: Products.csv
# ============================================================
#   Shape: 2517 rows x 10 columns
#   Columns: ['ProductKey', 'Product Name', 'Brand', 'Color', 'Unit Cost USD', 'Unit Price USD', 'SubcategoryKey', 'Subcategory', 'CategoryKey', 'Category']
#
#   Data Types:
#     ProductKey: int64
#     Product Name: object
#     Brand: object
#     Color: object
#     Unit Cost USD: object
#     Unit Price USD: object
#     SubcategoryKey: int64
#     Subcategory: object
#     CategoryKey: int64
#     Category: object
#
#   Missing Values:
#     ProductKey: 0 missing
#     Product Name: 0 missing
#     Brand: 0 missing
#     Color: 0 missing
#     Unit Cost USD: 0 missing
#     Unit Price USD: 0 missing
#     SubcategoryKey: 0 missing
#     Subcategory: 0 missing
#     CategoryKey: 0 missing
#     Category: 0 missing
#
#   Duplicate Rows: 0
#
#   First 2 rows:
#  ProductKey                        Product Name   Brand  Color Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey Category
#           1 Contoso 512MB MP3 Player E51 Silver Contoso Silver        $6.62         $12.99              101     MP4&MP3            1    Audio
#           2   Contoso 512MB MP3 Player E51 Blue Contoso   Blue        $6.62         $12.99              101     MP4&MP3            1    Audio
#
# ============================================================
#   FILE: Sales.csv
# ============================================================
#   Shape: 62884 rows x 9 columns
#   Columns: ['Order Number', 'Line Item', 'Order Date', 'Delivery Date', 'CustomerKey', 'StoreKey', 'ProductKey', 'Quantity', 'Currency Code']
#
#   Data Types:
#     Order Number: int64
#     Line Item: int64
#     Order Date: object
#     Delivery Date: object
#     CustomerKey: int64
#     StoreKey: int64
#     ProductKey: int64
#     Quantity: int64
#     Currency Code: object
#
#   Missing Values:
#     Order Number: 0 missing
#     Line Item: 0 missing
#     Order Date: 0 missing
#     Delivery Date: 49719 missing (79.1%)
#     CustomerKey: 0 missing
#     StoreKey: 0 missing
#     ProductKey: 0 missing
#     Quantity: 0 missing
#     Currency Code: 0 missing
#
#   Duplicate Rows: 0
#
#   First 2 rows:
#  Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  ProductKey  Quantity Currency Code
#        366000          1   1/1/2016           NaN       265598        10        1304         1           CAD
#        366001          1   1/1/2016     1/13/2016      1269051         0        1048         2           USD
#
# ============================================================
#   FILE: Stores.csv
# ============================================================
#   Shape: 67 rows x 5 columns
#   Columns: ['StoreKey', 'Country', 'State', 'Square Meters', 'Open Date']
#
#   Data Types:
#     StoreKey: int64
#     Country: object
#     State: object
#     Square Meters: float64
#     Open Date: object
#
#   Missing Values:
#     StoreKey: 0 missing
#     Country: 0 missing
#     State: 0 missing
#     Square Meters: 1 missing (1.5%)
#     Open Date: 0 missing
#
#   Duplicate Rows: 0
#
#   First 2 rows:
#  StoreKey   Country                        State  Square Meters Open Date
#         1 Australia Australian Capital Territory          595.0  1/1/2008
#         2 Australia           Northern Territory          665.0 1/12/2008
#
# ============================================================
#   CROSS-TABLE OBSERVATIONS
# ============================================================
#
#   RELATIONSHIPS BETWEEN TABLES:
#     - Sales.CustomerKey  -> Customers.CustomerKey
#     - Sales.StoreKey     -> Stores.StoreKey
#     - Sales.ProductKey   -> Products.ProductKey
#     - Sales.CurrencyCode + Sales.Order Date -> Exchange_Rates.Currency + Exchange_Rates.Date
