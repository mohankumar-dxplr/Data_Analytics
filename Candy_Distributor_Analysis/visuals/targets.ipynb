# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("C:/Users/Mohan/Documents/Candy Distribution Performance Dashboard & Market Intelligence System/final_data/Candy_Targets.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Division  3 non-null      object
#  1   Target    3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.head()
# Out:
#     Division  Target
# 0  Chocolate   27000
# 1      Sugar   15000
# 2      Other    3000

# %%
df["Division"] = df["Division"].astype("string")

# %%
df.plot(
    kind='bar',
    x='Division',
    y='Target',
    xlabel="Division",
    ylabel="Target"
)
# Out:
# <Axes: xlabel='Division', ylabel='Target'>
