# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_targets = pd.read_csv("C:/Users/Mohan/Documents/Candy/data/version_0/Candy_Targets.csv")

# %%
df_targets.head()
# Out:
#     Division  Target
# 0  Chocolate   27000
# 1      Sugar   15000
# 2      Other    3000

# %%
df_targets.shape
# Out:
# (3, 2)

# %%
df_targets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Division  3 non-null      str
#  1   Target    3 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 180.0 bytes

# %%
df_targets.describe()
# Out:
#         Target
# count      3.0
# mean   15000.0
# std    12000.0
# min     3000.0
# 25%     9000.0
# 50%    15000.0
# 75%    21000.0
# max    27000.0

# %%
df_targets["Division"] = df_targets["Division"].astype("string")

# %%
print(df_targets["Division"].dtype)
# Out:
# string

# %%
df_targets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Division  3 non-null      string
#  1   Target    3 non-null      int64
# dtypes: int64(1), string(1)
# memory usage: 180.0 bytes

# %%
df_targets.isnull().sum()
# Out:
# Division    0
# Target      0
# dtype: int64

# %%
df_targets.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
df_targets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Division  3 non-null      string
#  1   Target    3 non-null      int64
# dtypes: int64(1), string(1)
# memory usage: 180.0 bytes

# %%
# Save CSV
df_targets.to_csv("C:/Users/Mohan/Documents/Candy/data/version_1/Candy_Targets.csv", index=False)
