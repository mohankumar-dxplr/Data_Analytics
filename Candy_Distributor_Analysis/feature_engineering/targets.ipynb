# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("C:/Users/Mohan/Documents/candy/data/version_1/Candy_Targets.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Division  3 non-null      str
#  1   Target    3 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 180.0 bytes

# %%
df.head()
# Out:
#     Division  Target
# 0  Chocolate   27000
# 1      Sugar   15000
# 2      Other    3000

# %%
df["Division"] = df["Division"].astype("string")

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

scaler = MinMaxScaler()

df["Target"] = scaler.fit_transform(df[["Target"]])

print(df)
# Out:
#     Division  Target
# 0  Chocolate     1.0
# 1      Sugar     0.5
# 2      Other     0.0

# %%
df.to_csv("C:/Users/Mohan/Documents/candy/data/version_2/Candy_Targets.csv")
