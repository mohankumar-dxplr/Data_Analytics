# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_factory = pd.read_csv("C:/Users/Mohan/Documents/candy/data/version_1/Candy_Factories.csv")
df_products = pd.read_csv("C:/Users/Mohan/Documents/candy/data/version_1/Candy_Products.csv")
df_sales = pd.read_csv("C:/Users/Mohan/Documents/candy/data/version_1/Candy_Sales.csv")
df_targets = pd.read_csv("C:/Users/Mohan/Documents/candy/data/version_1/Candy_Targets.csv")
df_uszips = pd.read_csv("C:/Users/Mohan/Documents/candy/data/version_1/zips.csv")

# %%
df= df_products.merge(df_factory,on="Factory",how="left")

# %%
df= df.merge(df_targets,on="Division",how="left")

# %%
df= df_sales.merge(df,on="Product ID",how="left")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  str
#  2   Order Date      10194 non-null  str
#  3   Ship Date       10194 non-null  str
#  4   Ship Mode       10194 non-null  str
#  5   Customer ID     10194 non-null  int64
#  6   Country/Region  10194 non-null  str
#  7   City            10194 non-null  str
#  8   State/Province  10194 non-null  str
#  9   Postal Code     10194 non-null  str
#  10  Division_x      10194 non-null  str
#  11  Region          10194 non-null  str
#  12  Product ID      10194 non-null  str
#  13  Product Name_x  10194 non-null  str
#  14  Sales           10194 non-null  float64
#  15  Units           10194 non-null  int64
#  16  Gross Profit    10194 non-null  float64
#  17  Cost            10194 non-null  float64
# ...

# %%
mismatch = df[df["Division_x"] != df["Division_y"]]

print(mismatch[[
    "Row ID",
    "Product ID",
    "Product Name_x",
    "Division_x",
    "Division_y"
]].head())
# Out:
#       Row ID     Product ID        Product Name_x Division_x Division_y
# 1381    7380  OTH-FIZ-56000  Fizzy Lifting Drinks      Sugar      Other
# 3616    6737  OTH-FIZ-56000  Fizzy Lifting Drinks      Sugar      Other
# 6582    6913  OTH-FIZ-56000  Fizzy Lifting Drinks      Sugar      Other
# 7975     192  OTH-FIZ-56000  Fizzy Lifting Drinks      Sugar      Other
# 8970     228  OTH-FIZ-56000  Fizzy Lifting Drinks      Sugar      Other

# %%
len(mismatch)
# Out:
# 6

# %%
df.duplicated().unique()
# Out:
# array([False])

# %%
mismatch = df[df["Division_x"] != df["Division_y"]]

print("Mismatched rows:", len(mismatch))

mismatch[[
    "Row ID",
    "Product ID",
    "Product Name_x",
    "Division_x",
    "Division_y"
]].to_csv("division_mismatches.csv", index=False)
# Out:
# Mismatched rows: 6

# %%
print("Before:", len(df))

rows_to_remove = [7380, 6737, 6913, 192, 228, 2717]
df = df[~df["Row ID"].isin(rows_to_remove)]

print("After:", len(df))
# Out:
# Before: 10194
# After: 10188

# %%
(df["Product Name_x"] == df["Product Name_y"]).all()
# Out:
# np.True_

# %%
df = df.drop(columns=["Division_y","Product Name_y"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10188 entries, 0 to 10193
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10188 non-null  int64
#  1   Order ID        10188 non-null  str
#  2   Order Date      10188 non-null  str
#  3   Ship Date       10188 non-null  str
#  4   Ship Mode       10188 non-null  str
#  5   Customer ID     10188 non-null  int64
#  6   Country/Region  10188 non-null  str
#  7   City            10188 non-null  str
#  8   State/Province  10188 non-null  str
#  9   Postal Code     10188 non-null  str
#  10  Division_x      10188 non-null  str
#  11  Region          10188 non-null  str
#  12  Product ID      10188 non-null  str
#  13  Product Name_x  10188 non-null  str
#  14  Sales           10188 non-null  float64
#  15  Units           10188 non-null  int64
#  16  Gross Profit    10188 non-null  float64
#  17  Cost            10188 non-null  float64
# ...

# %%
df = df.rename(columns={'Division_x': 'Division','Product Name_x':'Product Name'})

# %%
df.head(5)
# Out:
#    Row ID                      Order ID  Order Date   Ship Date  \
# 0     282  US-2021-128055-CHO-TRI-54000  2021-03-31  2026-09-26
# 1     288  US-2021-128055-CHO-SCR-58000  2021-03-31  2026-09-26
# 2    1132  US-2021-138100-CHO-FUD-51000  2021-09-15  2027-03-13
# 3    1133  US-2021-138100-CHO-MIL-31000  2021-09-15  2027-03-13
# 4    3396  US-2022-121391-CHO-MIL-31000  2022-10-04  2028-03-29
#
#         Ship Mode  Customer ID Country/Region           City State/Province  \
# 0  Standard Class       128055  United States  San Francisco     California
# 1  Standard Class       128055  United States  San Francisco     California
# 2  Standard Class       138100  United States  New York City       New York
# 3  Standard Class       138100  United States  New York City       New York
# 4     First Class       121391  United States  San Francisco     California
#
#   Postal Code  ... Sales Units Gross Profit  Cost          Factory  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10188 entries, 0 to 10193
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10188 non-null  int64
#  1   Order ID        10188 non-null  str
#  2   Order Date      10188 non-null  str
#  3   Ship Date       10188 non-null  str
#  4   Ship Mode       10188 non-null  str
#  5   Customer ID     10188 non-null  int64
#  6   Country/Region  10188 non-null  str
#  7   City            10188 non-null  str
#  8   State/Province  10188 non-null  str
#  9   Postal Code     10188 non-null  str
#  10  Division        10188 non-null  str
#  11  Region          10188 non-null  str
#  12  Product ID      10188 non-null  str
#  13  Product Name    10188 non-null  str
#  14  Sales           10188 non-null  float64
#  15  Units           10188 non-null  int64
#  16  Gross Profit    10188 non-null  float64
#  17  Cost            10188 non-null  float64
# ...

# %%
df.duplicated().unique()
# Out:
# array([False])

# %%
df.to_csv("C:/Users/Mohan/Documents/candy/data/version_2/candy_data.csv")
